# %%
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support import expected_conditions
import json
import time
import uuid
import argparse

def getNewPaperId():
    return uuid.uuid4().hex[:8]


def initData():
    return {
        "name": None,  # string
        "id": getNewPaperId(),  # uuid
        "pdf_link": None,  # URL
        "metadata": {
            'words': []    # words to be associated with this paper
        },
        "authors": [], # list of strings
        "conference": None,  # string
        "year": None
    }

def getSubLink(elem):
    return elem.find_element_by_tag_name('a').get_attribute('href')

# %%
year = 2019
conference = "icml"
driver = webdriver.Chrome()
driver.implicitly_wait(10)
driver.get("http://proceedings.mlr.press/")

conf_data = []

# %%
conf_link = driver.find_element_by_xpath(
    f"//*[contains(text(), 'Proceedings of {conference.upper()} {year}')]")
print(conf_link)
# nips_link.click()

# conf_data = []
# papers = driver.find_elements_by_css_selector(
#     'body > div.main-container > div > ul > li')
# print(f"Processsing NIPS {year} with {len(papers)} papers")
# for paper in papers:
#     if len(conf_data) % 100 == 0:
#         print(len(conf_data))
#     data = initData()
#     pdf_link = paper.find_element_by_tag_name('a')
#     data['pdf_link'] = pdf_link.get_attribute('href') + '.pdf'
#     data['name'] = pdf_link.get_attribute('innerHTML')
#     data['conference'] = 'nips'
#     data['year'] = year
#     try:
#         paper.find_element_by_class_name('author')
#         authors = paper.find_elements_by_class_name('author')
#         for author in authors:
#             data['authors'].append(author.get_attribute('innerHTML'))
#     except:
#         pass
#     conf_data.append(data)
# Out:
# []

# %%
print(conf_data)
# Out:
# [{'name': 'Embodied Question Answering', 'id': '3002f6b8', 'pdf_link': 'http://openaccess.thecvf.com/content_cvpr_2018/papers/Das_Embodied_Question_Answering_CVPR_2018_paper.pdf', 'metadata': {'words': []}, 'authors': ['Abhishek Das', 'Samyak Datta', 'Georgia Gkioxari', 'Stefan Lee', 'Devi Parikh', 'Dhruv Batra'], 'conference': 'cvpr', 'year': 2018}, {'name': 'Learning by Asking Questions', 'id': 'f443d1a0', 'pdf_link': 'http://openaccess.thecvf.com/content_cvpr_2018/papers/Misra_Learning_by_Asking_CVPR_2018_paper.pdf', 'metadata': {'words': []}, 'authors': ['Ishan Misra', 'Ross Girshick', 'Rob Fergus', 'Martial Hebert', 'Abhinav Gupta', 'Laurens van der Maaten'], 'conference': 'cvpr', 'year': 2018}, {'name': 'Finding Tiny Faces in the Wild With Generative Adversarial Network', 'id': 'b8ce6e73', 'pdf_link': 'http://openaccess.thecvf.com/content_cvpr_2018/papers/Bai_Finding_Tiny_Faces_CVPR_2018_paper.pdf', 'metadata': {'words': []}, 'authors': ['Yancheng Bai', 'Yongqiang Zhang', 'Mingli Ding', 'Bernard Ghanem'], 'conference': 'cvpr', 'year': 2018}, {'name': 'Learning Face Age Progression: A Pyramid Architecture of GANs', 'id': '68879c94', 'pdf_link': 'http://openaccess.thecvf.com/content_cvpr_2018/papers/Yang_Learning_Face_Age_CVPR_2018_paper.pdf', 'metadata': {'words': []}, 'authors': ['Hongyu Yang', 'Di Huang', 'Yunhong Wang', 'Anil K. Jain'], 'conference': 'cvpr', 'year': 2018}, {'name': 'PairedCycleGAN: Asymmetric Style Transfer for Applying and Removing Makeup', 'id': '899ca550', 'pdf_link': 'http://openaccess.thecvf.com/content_cvpr_2018/papers/Chang_PairedCycleGAN_Asymmetric_Style_CVPR_2018_paper.pdf', 'metadata': {'words': []}, 'authors': ['Huiwen Chang', 'Jingwan Lu', 'Fisher Yu', 'Adam Finkelstein'], 'conference': 'cvpr', 'year': 2018}, {'name': 'GANerated Hands for Real-Time 3D Hand Tracking From Monocular RGB', 'id': 'dde5edf7', 'pdf_link': 'http://openaccess.thecvf.com/content_cvpr_2018/papers/Mueller_GANerated_Hands_for_CVPR_2018_paper.pdf', 'metadata': {'words': []}, 'authors': ['Franziska Mueller', 'Florian Bernard', 'Oleksandr Sotnychenko', 'Dushyant Mehta', 'Srinath Sridhar', 'Dan Casas', 'Christian Theobalt'], 'conference': 'cvpr', 'year': 2018}, {'name': 'Learning Pose Specific Representations by Predicting Different Views', 'id': '40312618', 'pdf_link': 'http://openaccess.thecvf.com/content_cvpr_2018/papers/Poier_Learning_Pose_Specific_CVPR_2018_paper.pdf', 'metadata': {'words': []}, 'authors': ['Georg Poier', 'David Schinagl', 'Horst Bischof'], 'conference': 'cvpr', 'year': 2018}, {'name': 'Weakly and Semi Supervised Human Body Part Parsing via Pose-Guided Knowledge Transfer', 'id': 'ec9a4a2d', 'pdf_link': 'http://openaccess.thecvf.com/content_cvpr_2018/papers/Fang_Weakly_and_Semi_CVPR_2018_paper.pdf', 'metadata': {'words': []}, 'authors': ['Hao-Shu Fang', 'Guansong Lu', 'Xiaolin Fang', 'Jianwen Xie', 'Yu-Wing Tai', 'Cewu Lu'], 'conference': 'cvpr', 'year': 2018}, {'name': 'Person Transfer GAN to Bridge Domain Gap for Person Re-Identification', 'id': 'afcbf15b', 'pdf_link': 'http://openaccess.thecvf.com/content_cvpr_2018/papers/Wei_Person_Transfer_GAN_CVPR_2018_paper.pdf', 'metadata': {'words': []}, 'authors': ['Longhui Wei', 'Shiliang Zhang', 'Wen Gao', 'Qi Tian'], 'conference': 'cvpr', 'year': 2018}, {'name': 'Cross-Modal Deep Variational Hand Pose Estimation', 'id': '4cb8a629', 'pdf_link': 'http://openaccess.thecvf.com/content_cvpr_2018/papers/Spurr_Cross-Modal_Deep_Variational_CVPR_2018_paper.pdf', 'metadata': {'words': []}, 'authors': ['Adrian Spurr', 'Jie Song', 'Seonwook Park', 'Otmar Hilliges'], 'conference': 'cvpr', 'year': 2018}, {'name': 'Disentangled Person Image Generation', 'id': '42c2c821', 'pdf_link': 'http://openaccess.thecvf.com/content_cvpr_2018/papers/Ma_Disentangled_Person_Image_CVPR_2018_paper.pdf', 'metadata': {'words': []}, 'authors': ['Liqian Ma', 'Qianru Sun', 'Stamatios Georgoulis', 'Luc Van Gool', 'Bernt Schiele', 'Mario Fritz'], 'conference': 'cvpr', 'year': 2018}, {'name': 'Su ...
